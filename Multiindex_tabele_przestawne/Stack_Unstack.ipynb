# %%
import pandas as pd
import numpy as np

# %%
incidents = pd.read_csv("./data/Canadian Railway Crossing Incidents.csv")
incidents.set_index(['Region','EventType'],inplace=True)
incidents.sort_index(inplace=True)

# %%
incidents.head(10)
# Out:
#                                    Public automated  Public passive  Private  \
# Region           EventType
# Alberta          Accidents                        3               7        2
#                  Fatalities                       0               0        0
#                  Serious injuries                 0               1        2
# British Columbia Accidents                        4               1        0
#                  Fatalities                       0               0        0
#                  Serious injuries                 3               0        0
# Manitoba         Accidents                        1               3        0
#                  Fatalities                       0               1        0
#                  Serious injuries                 0               0        0
# New Brunswick    Accidents                        0               0        0
#
#                                    Farm
# Region           EventType
# ...

# %%
incidents.stack().head()
# Out:
# Region   EventType
# Alberta  Accidents   Public automated    3
#                      Public passive      7
#                      Private             2
#                      Farm                0
#          Fatalities  Public automated    0
# dtype: int64

# %%
incidents.stack().to_frame().head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %%
stackIncidents = incidents.stack().to_frame()

# %%
stackIncidents.head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %%
stackIncidents.unstack().head()
# Out:
#                                                  0
#                                   Public automated Public passive Private Farm
# Region           EventType
# Alberta          Accidents                       3              7       2    0
#                  Fatalities                      0              0       0    0
#                  Serious injuries                0              1       2    0
# British Columbia Accidents                       4              1       0    0
#                  Fatalities                      0              0       0    0

# %%
stackIncidents.unstack().unstack().head()
# Out:
#                                 0                                             \
#                  Public automated                             Public passive
# EventType               Accidents Fatalities Serious injuries      Accidents
# Region
# Alberta                         3          0                0              7
# British Columbia                4          0                3              1
# Manitoba                        1          0                0              3
# New Brunswick                   0          0                0              0
# Newfoundland                    0          0                0              0
#
#                                                                    \
#                                                Private
# EventType        Fatalities Serious injuries Accidents Fatalities
# Region
# Alberta                   0                1         2          0
# British Columbia          0                0         0          0
# ...

# %%
stackIncidents.unstack(0).head()
# Out:
#                                   0                                          \
# Region                      Alberta British Columbia Manitoba New Brunswick
# EventType
# Accidents  Public automated       3                4        1             0
#            Public passive         7                1        3             0
#            Private                2                0        0             0
#            Farm                   0                0        2             0
# Fatalities Public automated       0                0        0             0
#
#                                                                             \
# Region                      Newfoundland Northwest Territories Nova Scotia
# EventType
# Accidents  Public automated            0                     0           1
#            Public passive              0                     0           0
#            Private                     0                     0           0
# ...

# %%
stackIncidents.unstack(level = 'Region').head()
# Out:
#                                   0                                          \
# Region                      Alberta British Columbia Manitoba New Brunswick
# EventType
# Accidents  Public automated       3                4        1             0
#            Public passive         7                1        3             0
#            Private                2                0        0             0
#            Farm                   0                0        2             0
# Fatalities Public automated       0                0        0             0
#
#                                                                             \
# Region                      Newfoundland Northwest Territories Nova Scotia
# EventType
# Accidents  Public automated            0                     0           1
#            Public passive              0                     0           0
#            Private                     0                     0           0
# ...

# %%
stackIncidents.head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %%
stackIncidents.unstack(level = ["Region",'EventType']).head()
# Out:
#                          0                                               \
# Region             Alberta                             British Columbia
# EventType        Accidents Fatalities Serious injuries        Accidents
# Public automated         3          0                0                4
# Public passive           7          0                1                1
# Private                  2          0                2                0
# Farm                     0          0                0                0
#
#                                                                    \
# Region                                        Manitoba
# EventType        Fatalities Serious injuries Accidents Fatalities
# Public automated          0                3         1          0
# Public passive            0                0         3          1
# Private                   0                0         0          0
# Farm                      0                0         2          0
#
# ...

# %%
stackIncidents.head()
# Out:
#                                      0
# Region  EventType
# Alberta Accidents  Public automated  3
#                    Public passive    7
#                    Private           2
#                    Farm              0
#         Fatalities Public automated  0

# %%
stackIncidents.loc[("Alberta","Accidents","Private")]
# Out:
# 0    2
# Name: (Alberta, Accidents, Private), dtype: int64

# %%
stackIncidents.loc[('Alberta','Accidents','Private'),0]
# Out:
# 2

# %%
incidents.unstack().stack()
## te same
# Out:
#                                         Public automated  Public passive  \
# Region                EventType
# Alberta               Accidents                        3               7
#                       Fatalities                       0               0
#                       Serious injuries                 0               1
# British Columbia      Accidents                        4               1
#                       Fatalities                       0               0
#                       Serious injuries                 3               0
# Manitoba              Accidents                        1               3
#                       Fatalities                       0               1
#                       Serious injuries                 0               0
# New Brunswick         Accidents                        0               0
#                       Fatalities                       0               0
# ...
