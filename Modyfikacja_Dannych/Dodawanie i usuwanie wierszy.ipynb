# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
frame = pd.read_csv('./Data/sleep_time.csv')

# %%
frame.head()
# Out:
#    ID                        name       genus   vore         order  \
# 0   1                     Cheetah    Acinonyx  carni     Carnivora
# 1   2                  Owl monkey       Aotus   omni      Primates
# 2   3             Mountain beaver  Aplodontia  herbi      Rodentia
# 3   4  Greater short-tailed shrew     Blarina   omni  Soricomorpha
# 4   5                         Cow         Bos  herbi  Artiodactyla
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt   bodywt
# 0            lc         12.1        NaN          NaN   11.9      NaN   50.000
# 1           NaN         17.0        1.8          NaN    7.0  0.01550    0.480
# 2            nt         14.4        2.4          NaN    9.6      NaN    1.350
# 3            lc         14.9        2.3     0.133333    9.1  0.00029    0.019
# 4  domesticated          4.0        0.7     0.666667   20.0  0.42300  600.000

# %%
del frame["bodywt"]

# %%
frame.head()
# Out:
#    ID                        name       genus   vore         order  \
# 0   1                     Cheetah    Acinonyx  carni     Carnivora
# 1   2                  Owl monkey       Aotus   omni      Primates
# 2   3             Mountain beaver  Aplodontia  herbi      Rodentia
# 3   4  Greater short-tailed shrew     Blarina   omni  Soricomorpha
# 4   5                         Cow         Bos  herbi  Artiodactyla
#
#    conservation  sleep_total  sleep_rem  sleep_cycle  awake  brainwt
# 0            lc         12.1        NaN          NaN   11.9      NaN
# 1           NaN         17.0        1.8          NaN    7.0  0.01550
# 2            nt         14.4        2.4          NaN    9.6      NaN
# 3            lc         14.9        2.3     0.133333    9.1  0.00029
# 4  domesticated          4.0        0.7     0.666667   20.0  0.42300

# %%
frame.drop(axis=1, columns=['awake','brainwt'],inplace=True)

# %%
frame.head()
# Out:
#    ID                        name       genus   vore         order  \
# 0   1                     Cheetah    Acinonyx  carni     Carnivora
# 1   2                  Owl monkey       Aotus   omni      Primates
# 2   3             Mountain beaver  Aplodontia  herbi      Rodentia
# 3   4  Greater short-tailed shrew     Blarina   omni  Soricomorpha
# 4   5                         Cow         Bos  herbi  Artiodactyla
#
#    conservation  sleep_total  sleep_rem  sleep_cycle
# 0            lc         12.1        NaN          NaN
# 1           NaN         17.0        1.8          NaN
# 2            nt         14.4        2.4          NaN
# 3            lc         14.9        2.3     0.133333
# 4  domesticated          4.0        0.7     0.666667

# %%
frame.drop(axis='columns',columns ='sleep_cycle',inplace=True)

# %%
frame.drop(columns='sleep_rem',inplace=True)

# %%
frame.head()
# Out:
#    ID                        name       genus   vore         order  \
# 0   1                     Cheetah    Acinonyx  carni     Carnivora
# 1   2                  Owl monkey       Aotus   omni      Primates
# 2   3             Mountain beaver  Aplodontia  herbi      Rodentia
# 3   4  Greater short-tailed shrew     Blarina   omni  Soricomorpha
# 4   5                         Cow         Bos  herbi  Artiodactyla
#
#    conservation  sleep_total
# 0            lc         12.1
# 1           NaN         17.0
# 2            nt         14.4
# 3            lc         14.9
# 4  domesticated          4.0

# %%
frame.drop(axis=0, labels = [1,2],inplace=True)

# %%
frame.head()
# Out:
#    ID                        name        genus   vore         order  \
# 0   1                     Cheetah     Acinonyx  carni     Carnivora
# 3   4  Greater short-tailed shrew      Blarina   omni  Soricomorpha
# 4   5                         Cow          Bos  herbi  Artiodactyla
# 5   6            Three-toed sloth     Bradypus  herbi        Pilosa
# 6   7           Northern fur seal  Callorhinus  carni     Carnivora
#
#    conservation  sleep_total
# 0            lc         12.1
# 3            lc         14.9
# 4  domesticated          4.0
# 5           NaN         14.4
# 6            vu          8.7

# %%
frame.drop(axis = 'rows', labels = 3, inplace=True)

# %%
frame.head()
# Out:
#    ID               name        genus   vore         order  conservation  \
# 0   1            Cheetah     Acinonyx  carni     Carnivora            lc
# 4   5                Cow          Bos  herbi  Artiodactyla  domesticated
# 5   6   Three-toed sloth     Bradypus  herbi        Pilosa           NaN
# 6   7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7   8       Vesper mouse      Calomys    NaN      Rodentia           NaN
#
#    sleep_total
# 0         12.1
# 4          4.0
# 5         14.4
# 6          8.7
# 7          7.0

# %%
frame.drop(labels =4, inplace=True)

# %%
frame.head()
# Out:
#    ID               name        genus   vore      order  conservation  \
# 0   1            Cheetah     Acinonyx  carni  Carnivora            lc
# 5   6   Three-toed sloth     Bradypus  herbi     Pilosa           NaN
# 6   7  Northern fur seal  Callorhinus  carni  Carnivora            vu
# 7   8       Vesper mouse      Calomys    NaN   Rodentia           NaN
# 8   9                Dog        Canis  carni  Carnivora  domesticated
#
#    sleep_total
# 0         12.1
# 5         14.4
# 6          8.7
# 7          7.0
# 8         10.1

# %%
frame.drop(5, inplace=True)

# %%
frame.head()
# Out:
#    ID               name        genus   vore         order  conservation  \
# 0   1            Cheetah     Acinonyx  carni     Carnivora            lc
# 6   7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7   8       Vesper mouse      Calomys    NaN      Rodentia           NaN
# 8   9                Dog        Canis  carni     Carnivora  domesticated
# 9  10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#    sleep_total
# 0         12.1
# 6          8.7
# 7          7.0
# 8         10.1
# 9          3.0

# %%
frame.append({'name':'Pandas4','genus':np.NaN,'order':np.NaN,'conservation':np.NaN,'sleep_total':10},ignore_index=True)
Panda = frame['name'] == 'Pandas4'
Panda
# Out:
# 0    False
# 6    False
# 7    False
# 8    False
# 9    False
#      ...
# 0    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, Length: 83, dtype: bool

# %%
subset = frame[0:5]

# %%
subset
# Out:
#    ID               name        genus   vore         order  conservation  \
# 0   1            Cheetah     Acinonyx  carni     Carnivora            lc
# 6   7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7   8       Vesper mouse      Calomys    NaN      Rodentia           NaN
# 8   9                Dog        Canis  carni     Carnivora  domesticated
# 9  10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#    sleep_total
# 0         12.1
# 6          8.7
# 7          7.0
# 8         10.1
# 9          3.0

# %%
frame.append(subset)
# Out:
#     ID               name        genus   vore         order  conservation  \
# 0    1            Cheetah     Acinonyx  carni     Carnivora            lc
# 6    7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7    8       Vesper mouse      Calomys    NaN      Rodentia           NaN
# 8    9                Dog        Canis  carni     Carnivora  domesticated
# 9   10           Roe deer    Capreolus  herbi  Artiodactyla            lc
# ..  ..                ...          ...    ...           ...           ...
# 0    1            Cheetah     Acinonyx  carni     Carnivora            lc
# 6    7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7    8       Vesper mouse      Calomys    NaN      Rodentia           NaN
# 8    9                Dog        Canis  carni     Carnivora  domesticated
# 9   10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total
# 0          12.1
# 6           8.7
# 7           7.0
# 8          10.1
# 9           3.0
# ..          ...
# 0          12.1
# 6           8.7
# 7           7.0
# 8          10.1
# 9           3.0
#
# [83 rows x 7 columns]

# %%
frame = frame.append(subset)

# %%
frame
# Out:
#     ID               name        genus   vore         order  conservation  \
# 0    1            Cheetah     Acinonyx  carni     Carnivora            lc
# 6    7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7    8       Vesper mouse      Calomys    NaN      Rodentia           NaN
# 8    9                Dog        Canis  carni     Carnivora  domesticated
# 9   10           Roe deer    Capreolus  herbi  Artiodactyla            lc
# ..  ..                ...          ...    ...           ...           ...
# 0    1            Cheetah     Acinonyx  carni     Carnivora            lc
# 6    7  Northern fur seal  Callorhinus  carni     Carnivora            vu
# 7    8       Vesper mouse      Calomys    NaN      Rodentia           NaN
# 8    9                Dog        Canis  carni     Carnivora  domesticated
# 9   10           Roe deer    Capreolus  herbi  Artiodactyla            lc
#
#     sleep_total
# 0          12.1
# 6           8.7
# 7           7.0
# 8          10.1
# 9           3.0
# ..          ...
# 0          12.1
# 6           8.7
# 7           7.0
# 8          10.1
# 9           3.0
#
# [83 rows x 7 columns]

# %%
frame.loc[82]
# Out:
# ID                     83
# name              Red fox
# genus              Vulpes
# vore                carni
# order           Carnivora
# conservation          NaN
# sleep_total           9.8
# Name: 82, dtype: object

# %%
frame['name'] == 'Pandas4'
# Out:
# 0    False
# 6    False
# 7    False
# 8    False
# 9    False
#      ...
# 0    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, Length: 83, dtype: bool

# %%
frame['name'] == 'Cheetah'
# Out:
# 0     True
# 6    False
# 7    False
# 8    False
# 9    False
#      ...
# 0     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: name, Length: 83, dtype: bool

# %%
frame.loc[0]
# Out:
#    ID     name     genus   vore      order conservation  sleep_total
# 0   1  Cheetah  Acinonyx  carni  Carnivora           lc         12.1
# 0   1  Cheetah  Acinonyx  carni  Carnivora           lc         12.1
